# %%
from dotenv import load_dotenv
load_dotenv()
import os


if os.environ.get("GEMINI_API_KEY"):
    print("GEMINI_API_KEY is set.")
# Out:
# GEMINI_API_KEY is set.

# %% [markdown]
# GEMINI SDK

# %%
from google import genai

# The client gets the API key from the environment variable `GEMINI_API_KEY`.
client = genai.Client()

response = client.models.generate_content(
    model="gemini-3.5-flash", 
    contents="Tell me a fun fact about Data Domain"
)
print(response.text)
# Out:
# Here is a fun fact about Data Domain: **It sparked one of the most intense, high-stakes bidding wars in Silicon Valley history, changing the storage industry forever.**
#
# In 2009, Data Domain was the hottest ticket in tech because their "deduplication" technology was single-handedly killing off magnetic backup tapes.
#
# Storage giant **NetApp** made a friendly offer to buy Data Domain for $1.5 billion. But **EMC** (now Dell EMC) decided they couldn't let their rival get this technology. EMC swooped in with a hostile cash bid of $1.8 billion.
#
# What followed was a wild, multi-week game of corporate poker:
# * NetApp raised their bid to $1.9 billion.
# * EMC immediately countered with $2.1 billion in cold, hard cash.
# * NetApp realized they couldn't compete with EMC's war chest and backed out (though they walked away with a $57 million breakup fee).
#
# **Why the frenzy?**
# Before Data Domain, companies backed up their data to physical tapes, which were literally transported in trucks to secure warehouses. Data Domain’s deduplication was so good that it shrank data by a ratio of **20:1 or more**, allowing companies to finally ditch the tapes and back up over the internet.
#
# EMC’s $2.1 billion gamble paid off massively—Data Domain became the undisputed crown jewel of their backup division, and to this day (under Dell), it remains the market leader in data protection.
